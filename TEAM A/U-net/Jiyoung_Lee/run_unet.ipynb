# %%
# 구글 드라이브 연결
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/자이/1주차
# Out:
# /content/drive/MyDrive/자이/1주차

# %%
# 데이터 생성
# !python data_read.py
# Out:
# Figure(640x480)

# %%
# 학습 실행
# !python train.py \
--lr 1e-3 \
--batch_size 2 \
--num_epoch 5 \
--data_dir ./datasets \
--ckpt_dir ./saved_model \
--log_dir ./log \
--result_dir ./result \
--mode train \
--train_continue off
# Out:
# EPOCH 1 | LOSS 0.5047
# EPOCH 2 | LOSS 0.3467
# EPOCH 3 | LOSS 0.2941
# EPOCH 4 | LOSS 0.2708
# EPOCH 5 | LOSS 0.2489
# 학습 완료

# %%
# 테스트 실행
# !python train.py \
--lr 1e-3 \
--batch_size 2 \
--num_epoch 5 \
--data_dir ./datasets \
--ckpt_dir ./saved_model \
--log_dir ./log \
--result_dir ./result \
--mode test \
--train_continue on
# Out:
# EPOCH 1 | LOSS 0.4490
# EPOCH 2 | LOSS 0.3123
# EPOCH 3 | LOSS 0.2661
# EPOCH 4 | LOSS 0.2463
# EPOCH 5 | LOSS 0.2273
# 학습 완료
