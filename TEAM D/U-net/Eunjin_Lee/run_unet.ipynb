# %%
# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
tensorboard --logdir='log'

# %%
# !python3 'train.py'
# Out:
# learning rate: 1.0000e-03
# batch size: 4
# number of epoch: 100
# data dir: datasets
# ckpt dir: checkpoint
# log dir: log
# result dir: results
# mode: train
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# TRAIN: EPOCH 0001 / 0100 | BATCH 0001 / 0006 | LOSS 0.8065
# TRAIN: EPOCH 0001 / 0100 | BATCH 0002 / 0006 | LOSS 0.7430
# TRAIN: EPOCH 0001 / 0100 | BATCH 0003 / 0006 | LOSS 0.6971
# TRAIN: EPOCH 0001 / 0100 | BATCH 0004 / 0006 | LOSS 0.6732
# TRAIN: EPOCH 0001 / 0100 | BATCH 0005 / 0006 | LOSS 0.6485
# TRAIN: EPOCH 0001 / 0100 | BATCH 0006 / 0006 | LOSS 0.6318
# ...

# %%
# !python3 "train.py" \
--lr 1e-2 --batch_size 2 --num_epoch 300 \
--data_dir "datasets" \
--ckpt_dir "checkpoint" \
--log_dir "log" \
--result_dir "results" \
--mode "test" \
--train_continue "off"
# Out:
# learning rate: 1.0000e-02
# batch size: 2
# number of epoch: 300
# data dir: datasets
# ckpt dir: checkpoint
# log dir: log
# result dir: results
# mode: test
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# TEST: BATCH 0001 / 0002 | LOSS 0.1813
# TEST: BATCH 0002 / 0002 | LOSS 0.1803
# AVERAGE TEST: BATCH 0002 / 0002 | LOSS 0.1803
